# %% [markdown]
# # Web Scraping, a.k.a. `lyrics`

# %% [markdown]
# ### 🎯 Goal: scarpe lyrics from EMINEM and MADONNA

# %%
import requests
import re
import time
from bs4 import BeautifulSoup

import pandas as pd

# %% [markdown]
# Requests allows us to send HTTP requests to website/servers. It sends back a response code, and the full html (if successful).

# %%
# example with spiced academy

# avoid getting blocked 
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}

url_mad = 'https://www.lyrics.com/artist/Madonna/64565'

# %%
response_mad = requests.get(url_mad, headers=headers)
response_mad.text
# Out:
# '\n<!doctype html>\n<!--[if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="en"> <![endif]-->\n<!--[if IE 7]>    <html class="no-js lt-ie9 lt-ie8" lang="en"> <![endif]-->\n<!--[if IE 8]>    <html class="no-js lt-ie9" lang="en"> <![endif]-->\n<!--[if gt IE 8]><!--> <html class="no-js" lang="en"> <!--<![endif]--><head>\n<meta charset="utf-8">\n<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n<title>Madonna Lyrics, Songs and Albums | Lyrics.com</title>\n<meta name="description" content="Madonna Lyrics - All the great songs and their lyrics from Madonna on Lyrics.com">\n<meta name="keywords" content="Madonna lyrics, Madonna song lyrics, Madonna lyric">\n<meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1">\n<base href="https://www.lyrics.com/">\n\n<script>\ns4Prefix = \'https://static.stands4.com\';\nversion = \'1.3.79\';\n</script>\n\n<!-- Bootstrap compiled and minified CSS -->\n<link rel="stylesheet" href="https://maxcdn.bootstra
# ...

# %%
response_mad.status_code
# Out:
# 200

# %% [markdown]
# # Starting with **Beautiful Soup**

# %%
soup_mad = BeautifulSoup(response_mad.text, 'html.parser')
soup_mad
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="en"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js lt-ie9 lt-ie8" lang="en"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js lt-ie9" lang="en"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en"> <!--<![endif]--><head>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>Madonna Lyrics, Songs and Albums | Lyrics.com</title>
# <meta content="Madonna Lyrics - All the great songs and their lyrics from Madonna on Lyrics.com" name="description"/>
# <meta content="Madonna lyrics, Madonna song lyrics, Madonna lyric" name="keywords"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <base href="https://www.lyrics.com/"/>
# <script>
# s4Prefix = 'https://static.stands4.com';
# version = '1.3.79';
# </script>
# <!-- Bootstrap compiled and minified CSS -->
# ...

# %%
soup_mad.head.title.text
# Out:
# 'Madonna Lyrics, Songs and Albums | Lyrics.com'

# %% [markdown]
# ## Getting all lyric titles in the html page
#
# * FIRST: get individual reference first to see where it is

# %%
soup_mad.find(class_="tal qx").a['href']
# Out:
# '/lyric/36050507/Madonna/Live+to+Tell'

# %%
# another way
#soup_mad.find('td', attrs={'class':'tal qx'}).text

# %%
# use find_all for MADONNA
all_mado_titles = soup_mad.find_all(class_='tal qx')

#empty list to append all title names

titles_mad = []

for title in all_mado_titles:
    titles_mad.append(title.a.text)

# %%
titles_mad
# Out:
# ['Live to Tell',
#  'Holiday',
#  'Like a Virgin',
#  'Soltera',
#  'Crave',
#  'Dark Ballet',
#  'Future',
#  'I Rise',
#  'Like a Prayer',
#  'Music',
#  'Medellín',
#  'Dark Ballet',
#  'God Control',
#  'Future',
#  'Crave',
#  'Crazy',
#  "Bitch I'm Loca",
#  'I Rise',
#  'Medellín',
#  'Open Your Heart',
#  'Holiday',
#  'Into the Groove',
#  'CHAMPAGNE ROSÉ',
#  'Open Your Heart',
#  'Lucky Star',
#  'True Blue',
#  'White Heat',
#  'Causing a Commotion',
#  'The Look of Love',
#  'Like a Virgin',
#  "Where's the Party?",
#  'Into the Groove',
#  "Who's That Girl?",
#  'Express Yourself',
#  'Sooner or Later',
#  'Fever',
#  'Bad Girl',
#  'Bye Bye Baby',
#  'Take a Bow',
#  'Crazy for You',
#  'Over and Over',
#  'Burning Up',
#  'Open Your Heart',
#  'Lucky Star',
#  'True Blue',
#  "Papa Don't Preach",
#  'White Heat',
#  'Causing a Commotion',
#  'The Look of Love',
#  'Material Girl',
#  'Like a Virgin',
#  "Where's the Party?",
#  'Live to Tell',
#  'Into the Groove',
# ...

# %% [markdown]
# ## Extract the song **links**

# %%
# individually 

"www.lyrics.com" + soup_mad.find('td', attrs={'class' : 'tal qx'}).a['href']
# Out:
# 'www.lyrics.com/lyric/36050507/Madonna/Live+to+Tell'

# %%
#madonna 
links_mad = []

poemlinks = soup_mad.find_all('td', attrs={'class' : 'tal qx'})
for link in poemlinks:
    links_mad.append("http://www.lyrics.com" + link.a['href'])
links_mad
# Out:
# ['http://www.lyrics.com/lyric/36050507/Madonna/Live+to+Tell',
#  'http://www.lyrics.com/lyric/36111222/Madonna/Holiday',
#  'http://www.lyrics.com/lyric/36111174/Madonna/Like+a+Virgin',
#  'http://www.lyrics.com/lyric/36233895/Madonna/Soltera',
#  'http://www.lyrics.com/lyric/36227884/Madonna/Crave',
#  'http://www.lyrics.com/lyric/36278799/Madonna/Dark+Ballet',
#  'http://www.lyrics.com/lyric/36210392/Madonna/Future',
#  'http://www.lyrics.com/lyric/36206725/Madonna/I+Rise',
#  'http://www.lyrics.com/lyric/36341851/Madonna/Like+a+Prayer',
#  'http://www.lyrics.com/lyric/36341853/Madonna/Music',
#  'http://www.lyrics.com/lyric/36290739/Madonna/Medell%C3%ADn',
#  'http://www.lyrics.com/lyric/36290738/Madonna/Dark+Ballet',
#  'http://www.lyrics.com/lyric/36290737/Madonna/God+Control',
#  'http://www.lyrics.com/lyric/36290736/Madonna/Future',
#  'http://www.lyrics.com/lyric/36290733/Madonna/Crave',
#  'http://www.lyrics.com/lyric/36290732/Madonna/Crazy',
# ...

# %% [markdown]
# ## Create DataFrame

# %%
madonna = pd.DataFrame({'title': titles_mad, 'links':links_mad})
madonna
# Out:
#                                    title  \
# 0                           Live to Tell
# 1                                Holiday
# 2                          Like a Virgin
# 3                                Soltera
# 4                                  Crave
# ...                                  ...
# 2908    Another Suitcase in Another Hall
# 2909  Who's That Girl [Extended Version]
# 2910                        Wild Dancing
# 2911                       On the Street
# 2912                          You'll See
#
#                                                   links
# 0     http://www.lyrics.com/lyric/36050507/Madonna/L...
# 1     http://www.lyrics.com/lyric/36111222/Madonna/H...
# 2     http://www.lyrics.com/lyric/36111174/Madonna/L...
# 3     http://www.lyrics.com/lyric/36233895/Madonna/S...
# 4     http://www.lyrics.com/lyric/36227884/Madonna/C...
# ...                                                 ...
# 2908  http://www.lyrics.com/lyric/35097435/Madonna/A...
# ...

# %% [markdown]
# # Clean **MADONNA** df

# %%
# shape --> 2913 rows × 2 columns
madonna
# Out:
#                                    title  \
# 0                           Live to Tell
# 1                                Holiday
# 2                          Like a Virgin
# 3                                Soltera
# 4                                  Crave
# ...                                  ...
# 2908    Another Suitcase in Another Hall
# 2909  Who's That Girl [Extended Version]
# 2910                        Wild Dancing
# 2911                       On the Street
# 2912                          You'll See
#
#                                                   links
# 0     http://www.lyrics.com/lyric/36050507/Madonna/L...
# 1     http://www.lyrics.com/lyric/36111222/Madonna/H...
# 2     http://www.lyrics.com/lyric/36111174/Madonna/L...
# 3     http://www.lyrics.com/lyric/36233895/Madonna/S...
# 4     http://www.lyrics.com/lyric/36227884/Madonna/C...
# ...                                                 ...
# 2908  http://www.lyrics.com/lyric/35097435/Madonna/A...
# ...

# %%
for i in range(len(madonna)):
    madonna.title[i] = madonna.title[i].split('[')[0]
    madonna.title[i] = madonna.title[i].split('(')[0]
    madonna.title[i] = madonna.title[i].lower()

# %%
madonna['title'].value_counts()
# Out:
# holiday                      48
# like a virgin                45
# music                        41
# la isla bonita               39
# material girl                38
#                              ..
# history                       1
# imagine                       1
# act 2. rainbow tour           1
# act 1. a new argentina        1
# future lovers/i feel love     1
# Name: title, Length: 430, dtype: int64

# %%
madonna.drop_duplicates(subset='title', inplace=True)

# %%
madonna.reset_index(inplace=True, drop=True)

# %% [markdown]
# ## Creating new column with lyrics
#
# * df is cleaned from repeated songs
#     * all lower case
#     * no []
#     * no ()

# %%
# creating a new column first filled in with black
madonna[['song_lyric', 'artist']] = ['blank', '1']

# %%
madonna    # shape --> 430 rows × 3 columns
# Out:
#                          title  \
# 0                 live to tell
# 1                      holiday
# 2                like a virgin
# 3                      soltera
# 4                        crave
# ..                         ...
# 425          looking for mercy
# 426       goodbye to innocence
# 427                    revenge
# 428               it's so cool
# 429  future lovers/i feel love
#
#                                                  links song_lyric artist
# 0    http://www.lyrics.com/lyric/36050507/Madonna/L...      blank      1
# 1    http://www.lyrics.com/lyric/36111222/Madonna/H...      blank      1
# 2    http://www.lyrics.com/lyric/36111174/Madonna/L...      blank      1
# 3    http://www.lyrics.com/lyric/36233895/Madonna/S...      blank      1
# 4    http://www.lyrics.com/lyric/36227884/Madonna/C...      blank      1
# ..                                                 ...        ...    ...
# ...

# %% [markdown]
# ## Madonna

# %%
for i in range(len(madonna.links)):
    try:
        lyric = BeautifulSoup(requests.get(madonna.links[i]).text)
        madonna['song_lyric'][i] = lyric.find('pre', attrs={'id':'lyric-body-text'}).text
        time.sleep(4)
    except:
        print('Something wrong with file: ', madonna.links[i])
        #print(exception, df.file[i])
        madonna['song_lyric'] = 'NaN'
        # question, there is a fuckton of generated NaN without exception generated...
        continue
# Out:
# Something wrong with file:  http://www.lyrics.com/lyric/8542380/Madonna/Fighting+Spirit
# Something wrong with file:  http://www.lyrics.com/lyric/7423019/Madonna/Nothing+Fails+%5BNevins+Global+Dub%5D
# Something wrong with file:  http://www.lyrics.com/lyric/4097841/Madonna/Cyber-Raga+%5B%2A%5D
# Something wrong with file:  http://www.lyrics.com/lyric/10399575/Madonna/Cyber-Raga
# Something wrong with file:  http://www.lyrics.com/lyric/98835/Madonna/This+Used+to+Be+My+Playground+%5BInstrumental%5D
# Something wrong with file:  http://www.lyrics.com/lyric/3170880/Madonna/Wild+Dancing
# Something wrong with file:  http://www.lyrics.com/lyric/3170884/Madonna/On+the+Street
# Something wrong with file:  http://www.lyrics.com/lyric/23042494/Madonna/Time+to+Dance+%5BInstrumental+Mix%5D
# Something wrong with file:  http://www.lyrics.com/lyric/23042493/Madonna/Shake+%5BInstrumental+Mix%5D
# ...

# %%
madonna
# Out:
#                          title  \
# 0                 live to tell
# 1                      holiday
# 2                like a virgin
# 3                      soltera
# 4                        crave
# ..                         ...
# 425          looking for mercy
# 426       goodbye to innocence
# 427                    revenge
# 428               it's so cool
# 429  future lovers/i feel love
#
#                                                  links  \
# 0    http://www.lyrics.com/lyric/36050507/Madonna/L...
# 1    http://www.lyrics.com/lyric/36111222/Madonna/H...
# 2    http://www.lyrics.com/lyric/36111174/Madonna/L...
# 3    http://www.lyrics.com/lyric/36233895/Madonna/S...
# 4    http://www.lyrics.com/lyric/36227884/Madonna/C...
# ..                                                 ...
# 425  http://www.lyrics.com/lyric-lf/1549886/Madonna...
# 426  http://www.lyrics.com/lyric-lf/3952434/Madonna...
# 427  http://www.lyrics.com/lyric-lf/3952449/Madonna...
# ...

# %%
madonna.to_csv('madonna_lyrics_final.csv')
